# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\envs\code\lib\site-packages (0.11.1)
# Requirement already satisfied: pandas>=0.23 in c:\programdata\anaconda3\envs\code\lib\site-packages (from seaborn) (1.2.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\programdata\anaconda3\envs\code\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: scipy>=1.0 in c:\programdata\anaconda3\envs\code\lib\site-packages (from seaborn) (1.6.3)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\anaconda3\envs\code\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\code\lib\site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\code\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\code\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\code\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\code\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\code\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\code\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import seaborn as sns

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]
df.head()
# Out:
#        Country  Year      Status  Life_expectancy_  Adult_Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles_  ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total_expenditure  Diphtheria_  _HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#    _thinness__1-19_years  _thinness_5-9_years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income_composition_of_resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
# drop columns which are not number (at future i will replace names with numbers)
df.drop(['Country', 'Status'], axis=1, inplace=True)

# %%
#Using Pearson Correlation for feature selection (using filter method)
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
# one way to make sure that linear regression is a good choice for our dataset in compare to non linear regression 
# is calculating correlation coefficient, if number is bigger than 0.7 then it shows linear regression is a good choice
cor_target = abs(cor["Life_expectancy_"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Life_expectancy_                   1.000000
# Adult_Mortality                    0.696359
# _BMI_                              0.567694
# _HIV/AIDS                          0.556556
# Income_composition_of_resources    0.724776
# Schooling                          0.751975
# Name: Life_expectancy_, dtype: float64

# %%
#One of the assumptions of linear regression is that the independent variables need to be uncorrelated with each other.
# If these variables are correlated with each other, then we need to keep only one of them and drop the rest.  
print(df[["Adult_Mortality","_BMI_"]].corr())
print('-----------------------------------------------------')
print(df[["_HIV/AIDS","Adult_Mortality"]].corr())
print('-----------------------------------------------------')
print(df[["Income_composition_of_resources","_HIV/AIDS"]].corr())
print('-----------------------------------------------------')
print(df[["Schooling","Adult_Mortality"]].corr())
print('-----------------------------------------------------')
print(df[["Schooling","_BMI_"]].corr())
print('-----------------------------------------------------')
print(df[["Income_composition_of_resources","_BMI_"]].corr())
# Out:
#                  Adult_Mortality     _BMI_
# Adult_Mortality         1.000000 -0.387017
# _BMI_                  -0.387017  1.000000
# -----------------------------------------------------
#                  _HIV/AIDS  Adult_Mortality
# _HIV/AIDS         1.000000         0.523821
# Adult_Mortality   0.523821         1.000000
# -----------------------------------------------------
#                                  Income_composition_of_resources  _HIV/AIDS
# Income_composition_of_resources                         1.000000  -0.249519
# _HIV/AIDS                                              -0.249519   1.000000
# -----------------------------------------------------
#                  Schooling  Adult_Mortality
# Schooling         1.000000        -0.454612
# Adult_Mortality  -0.454612         1.000000
# -----------------------------------------------------
#            Schooling     _BMI_
# Schooling   1.000000  0.546961
# _BMI_       0.546961  1.000000
# -----------------------------------------------------
#                                  Income_composition_of_resources     _BMI_
# Income_composition_of_resources                         1.000000  0.508774
# _BMI_                                                   0.508774  1.000000

# %%
# sns.pairplot(df, height=1.5, aspect=1.5)
# count number of null values in dataset
#df.isnull().values.sum()
# check whether there exicst null values
# df.isnull().values.sum()

# %%
# drop null values to clean data
df = df.dropna()

# %%
train, test = train_test_split(df, test_size=0.2)

# %%
X = train[['Schooling','Income_composition_of_resources', 'Adult_Mortality', '_BMI_']]
y = train['Life_expectancy_']

regr = linear_model.LinearRegression()
regr.fit(X, y)
# The coefficients
print('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [ 0.96334312 11.30302196 -0.03086274  0.0415621 ]

# %%
y_hat= regr.predict(test[['Schooling','Income_composition_of_resources', 'Adult_Mortality', '_BMI_']])
x = test[['Schooling','Income_composition_of_resources', 'Adult_Mortality', '_BMI_']]
y = test['Life_expectancy_']
print("Residual sum of squares: %.2f"% np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
#The best possible score is 1.0, the lower values are worse.
# Out:
# Residual sum of squares: 19.28
# Variance score: 0.74

# %%
# End
